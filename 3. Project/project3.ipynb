# %% [markdown]
# ### Step 2

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_expectancy = pd.read_csv('lex.csv', index_col='country')
df_population = pd.read_csv('pop.csv', index_col='country')
df_fertility = pd.read_csv('sp_dyn_tfrt_in.csv', index_col='country')

df_expectancy.shape, df_population.shape, df_fertility.shape
# Out:
# ((196, 301), (197, 301), (213, 63))

# %%
print(df_expectancy.columns)
df_expectancy.head()
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=301)
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  ...  \
# country                                                                  ...
# Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1  28.1  ...
# Angola       27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  ...
# Albania      35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  ...
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# UAE          30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  ...
#
#              2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# country
# Afghanistan  75.9  76.1  76.2  76.4  76.5  76.7  76.8  77.0  77.1  77.3
# ...

# %%
print(df_population.columns)
df_population.head()
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2091', '2092', '2093', '2094', '2095', '2096', '2097', '2098', '2099',
#        '2100'],
#       dtype='object', length=301)
#               1800   1801   1802   1803   1804   1805   1806   1807   1808  \
# country
# Afghanistan  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M  3.28M
# Angola       1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M  1.57M
# Albania       400k   402k   404k   405k   407k   409k   411k   413k   414k
# Andorra       2650   2650   2650   2650   2650   2650   2650   2650   2650
# UAE          40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k  40.2k
#
#               1809  ...   2091   2092   2093   2094   2095   2096   2097  \
# country             ...
# Afghanistan  3.28M  ...   124M   125M   126M   126M   127M   128M   128M
# Angola       1.57M  ...   139M   140M   142M   143M   144M   145M   147M
# ...

# %%
print(df_fertility.columns)
df_fertility.head()
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')
#              1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...  \
# country                                                                  ...
# Aruba        4.82  4.66  4.47  4.27  4.06  3.84  3.63  3.42  3.23  3.05  ...
# Afghanistan  7.28  7.28  7.29  7.30  7.30  7.30  7.32  7.34  7.36  7.39  ...
# Angola       6.71  6.79  6.87  6.95  7.04  7.12  7.19  7.27  7.33  7.39  ...
# ...

# %% [markdown]
# ### Step 3

# %%
fertility_2015 = df_fertility['2015']
expectancy_2015 = df_expectancy['2015']

fertility_expectancy_2015 = pd.merge(fertility_2015, expectancy_2015, on='country')
fertility_expectancy_2015.columns = ['fertility', 'life_expectancy']
fertility_expectancy_2015.head()
# Out:
#              fertility  life_expectancy
# country
# Afghanistan       5.41             61.9
# Angola            5.77             63.5
# Albania           1.61             78.1
# Andorra            NaN             82.0
# UAE               1.49             73.2

# %% [markdown]
# ### Step 4

# %%
fertility_expectancy_2015_clean = fertility_expectancy_2015.dropna()
fertility_expectancy_2015_clean.head()
# Out:
#              fertility  life_expectancy
# country
# Afghanistan       5.41             61.9
# Angola            5.77             63.5
# Albania           1.61             78.1
# UAE               1.49             73.2
# Argentina         2.30             76.5

# %% [markdown]
# ### Step 5

# %%
x=fertility_expectancy_2015_clean['fertility']
y=fertility_expectancy_2015_clean['life_expectancy']
plt.scatter((x), (y))
plt.xlabel('Fertility')
plt.ylabel('Life Expectancy')
plt.title('Fertility vs Life Expectancy in 2015')
plt.axis([0, 9, 25, 90])
plt.show()

# %% [markdown]
# ### Step 6

# %%
fertility_1960 = df_fertility['1960']
expectancy_1960 = df_expectancy['1960']

fertility_expectancy_1960 = pd.merge(fertility_1960, expectancy_1960, on='country')
fertility_expectancy_1960.columns = ['fertility', 'life_expectancy']

# %%
fertility_expectancy_1960_clean = fertility_expectancy_1960.dropna()

# %%
x=fertility_expectancy_1960_clean['fertility']
y=fertility_expectancy_1960_clean['life_expectancy']
plt.scatter((x), (y))
plt.xlabel('Fertility')
plt.ylabel('Life Expectancy')
plt.title('Fertility vs Life Expectancy in 1960')
plt.axis([0, 9, 25, 90])
plt.show()

# %% [markdown]
# When compared to the same axis, it is easier to see that in 1960 the life expectancy was much less than in 2015. However, fertility was bigger in 1960.

# %% [markdown]
# ### Step 7

# %%
def scatterplot_generator(year):
    fertility = df_fertility[year]
    expectancy = df_expectancy[year]

    fertility_expectancy = pd.merge(fertility, expectancy, on='country')
    fertility_expectancy.columns = ['fertility', 'life_expectancy']

    fertility_expectancy_clean = fertility_expectancy.dropna()

    x=fertility_expectancy_clean['fertility']
    y=fertility_expectancy_clean['life_expectancy']
    plt.scatter((x), (y))
    plt.xlabel('Fertility')
    plt.ylabel('Life Expectancy')
    plt.title('Fertility vs Life Expectancy in ' + year)
    plt.axis([0, 10, 20, 100])
    return plt

# %% [markdown]
# ### Step 8

# %%
for year in range(1960, 2011):
    plot = scatterplot_generator(str(year))
    plot.savefig('images/fertility_vs_life_expectancy_in_' + str(year) + '.png')
    plot.clf()

# %% [markdown]
# ### Step 9

# %%
import imageio.v2 as imageio

plots = [
    imageio.imread(f'images/fertility_vs_life_expectancy_in_{year}.png')
    for year in range(1960, 2011)
]

imageio.mimsave('fertility_vs_life_expectancy.gif', plots, fps=10)

# %% [markdown]
# ### Step 10

# %%
df_population.dropna(inplace=True)

def pop_convert(x):
    if isinstance(x, (int,float)):
        return int(x)
    if x.endswith('k'):
        result = float(x[:-1]) * 1000
        return int(result)
    elif x.endswith('M'):
        result = float(x[:-1]) * 1000000
        return int(result)
    elif x.endswith('B'):
        result = float(x[:-1]) * 1000000000
        return int(result)
    else:
        return int(x)

df_population= df_population.map(pop_convert)
df_population.head()
# Out:
#                 1800     1801     1802     1803     1804     1805     1806  \
# country
# Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# Angola       1570000  1570000  1570000  1570000  1570000  1570000  1570000
# Albania       400000   402000   404000   405000   407000   409000   411000
# Andorra         2650     2650     2650     2650     2650     2650     2650
# UAE            40200    40200    40200    40200    40200    40200    40200
#
#                 1807     1808     1809  ...       2091       2092       2093  \
# country                                 ...
# Afghanistan  3280000  3280000  3280000  ...  124000000  125000000  126000000
# Angola       1570000  1570000  1570000  ...  139000000  140000000  142000000
# Albania       413000   414000   416000  ...    1340000    1320000    1300000
# Andorra         2650     2650     2650  ...      52800      52100      51500
# UAE            40200    40200    40200  ...   24100000   24300000   24500000
# ...

# %% [markdown]
# ### Step 11

# %%
def devide_as_needed(x):
    return x/100000

df_population = df_population.map(devide_as_needed)

fertility = df_fertility['2015']
expectancy = df_expectancy['2015']
population = df_population['2015']

fertility_expectancy = pd.merge(fertility, expectancy, on='country')
fertility_expectancy_population = pd.merge(fertility_expectancy, population, on='country')
fertility_expectancy_population.columns = ['fertility', 'life_expectancy', 'population']

fertility_expectancy_population_clean = fertility_expectancy_population.dropna()

x=fertility_expectancy_population_clean['fertility']
y=fertility_expectancy_population_clean['life_expectancy']
s=fertility_expectancy_population_clean['population']

plt.scatter((x), (y), s=s)
plt.xlabel('Fertility')
plt.ylabel('Life Expectancy')
plt.title('Fertility vs Life Expectancy in 2015')
plt.axis([0, 10, 20, 100])
plt.show()

# %% [markdown]
# ### Step 12

# %%
df_continents = pd.read_csv('continents.csv', sep=';')
df_continents.head()

fertility_expectancy_population_continent = pd.merge(fertility_expectancy_population, df_continents, on='country')
fertility_expectancy_population_continent.dropna(inplace=True)

fertility_expectancy_population_continent_clean = fertility_expectancy_population_continent.dropna()

x=fertility_expectancy_population_continent_clean['fertility']
y=fertility_expectancy_population_continent_clean['life_expectancy']
s=fertility_expectancy_population_continent_clean['population']
color_guide = fertility_expectancy_population_continent_clean['continent']

sns.scatterplot(x=x, y=y, size=s, hue=color_guide, sizes=(20, 500), legend=False)
plt.xlabel('Fertility')
plt.ylabel('Life Expectancy')
plt.title('Fertility vs Life Expectancy in 2015')
plt.axis([0, 10, 20, 100])
plt.show()
